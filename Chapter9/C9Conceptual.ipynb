# %% [markdown]
# # 9.7 Concpetual Exercises

# %% [markdown]
# ## Question 1 - This problem involves hyperplanes in two dimensions.

# %% [markdown]
# ### (a) Sketch the hyperplane $1+3X_{1} − X_{2} = 0$. Indicate the set of points for which $1+3X_{1} − X_{2} > 0$, as well as the set of points for which $1+3X_{1} − X_{2} < 0$.

# %% [markdown]
# ### (b) On the same plot, sketch the hyperplane $−2 + X_{1} + 2X_{2} = 0$. Indicate the set of points for which $−2 + X_{1} + 2X_{2} > 0 $, as well as the set of points for which $−2 + X_{1} + 2X_{2} < 0$.

# %% [markdown]
# ### Answer - Question 1
#
# ![IMG_0036.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question 2 We have seen that in p = 2 dimensions, a linear decision boundary takes the form $β_{0}+β_{1}X_{1}+β_{2}X_{2} = 0$. We now investigate a non-linear decision boundary.

# %% [markdown]
# ### (a) Sketch the curve:
# > $(1 + X_{1})^{2} + (2 - X_{2})^{2} = 4$

# %% [markdown]
# ### (b) On your sketch, indicate the set of points for which
#
# >  $(1 + X_{1})^{2} + (2 - X_{2})^{2} ≤ 4$
#
# >  $(1 + X_{1})^{2} + (2 - X_{2})^{2} > 4$

# %% [markdown]
# ### (c) Suppose that a classifer assigns an observation to the blue class if $(1 + X_{1})^{2} + (2 - X_{2})^{2} > 4$ and to the red class for $(1 + X_{1})^{2} + (2 - X_{2})^{2} ≤ 4$
#
# > What are the following observations classified as:
# >> (0, 0),(−1, 1), (2, 2), (3, 8)

# %% [markdown]
# ### (d) Argue that while the decision boundary in (c) is not linear in terms of $X_{1}$ and $X_{2}$, it is linear in terms of $X_{1}$, $X_{1}^{2}$, $X_{2}$, and $X_{2}^{2}$

# %% [markdown]
# ### Answer - Question 2
#
# ![IMG_0035.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question 3. Here we explore the maximal margin classifer on a toy data set.

# %% [markdown]
# ### (a) We are given n = 7 observations in p = 2 dimensions. For each observation, there is an associated class label. Page 396 in the book. Sketch the observations.

# %% [markdown]
# ### (b) Sketch the optimal separating hyperplane, and provide the equation for this hyperplane (of the form (9.1)).

# %% [markdown]
# ### (c) Describe the classifcation rule for the maximal margin classifer. It should be something along the lines of “Classify to Red if $β_{0} + β_{1}X_{1} + β_{2}X_{2} > 0$, and classify to Blue otherwise.” Provide the values for $β_{0}, β_{1}, β_{2}$.

# %% [markdown]
# ### (d) On your sketch, indicate the margin for the maximal margin hyperplane.

# %% [markdown]
# ### (e) Indicate the support vectors for the maximal margin classifer

# %% [markdown]
# ### (f) Argue that a slight movement of the seventh observation would not afect the maximal margin hyperplane.
#
# * Based on the drawing below we see the support vectors are the only decisions that effect the maximal margin. Now the seventh observation is the point (4,1) which is not a support vectors. Thus it does not effect the maximal margin classifier.

# %% [markdown]
# ### (g) Sketch a hyperplane that is not the optimal separating hyperplane, and provide the equation for this hyperplane.

# %% [markdown]
# ### (h) Draw an additional observation on the plot so that the two classes are no longer separable by a hyperplane.

# %% [markdown]
# ### Answer - Question 3
#
# ![IMG_0037.jpg](data:image/jpeg;base64,...)
