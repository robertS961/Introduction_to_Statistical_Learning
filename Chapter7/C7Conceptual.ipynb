# %% [markdown]
# # 7.9 Conceptual Exercises

# %% [markdown]
# ## Question - 1. It was mentioned in this chapter that a cubic regression spline with one knot at ξ can be obtained using a basis of the form $x, x^{2}, x^{3},(x − ξ)_{+}^{3}, where (x − ξ)_{+}^{3} = (x − ξ)^{3}$ if x > ξ and equals 0 otherwise. We will now show that a function of the form:
#
# $f(x) = β_{0} + β_{1}x + β_{2}x^{2} + β_{3}x^{3} + β_{4}(x − ξ)_{+}^{3}$
#
# is indeed a cubic regression spline, regardless of the values of $β_{0}, β_{1}, β_{2}, β_{3}, β_{4}$

# %% [markdown]
# ### (a) Find a cubic polynomial
#
# $f_{1}(x) = a_{1} + b_{1}x + c_{1}x^{2} + d_{1}x^{3}$
#
# such that $f(x) = f_{1}(x)$ for all $x ≤ ξ$. Express $a_{1}, b_{1}, c_{1}, d_{1}$ in terms of $β_{0}, β_{1}, β_{2}, β_{3}, β_{4}$

# %% [markdown]
# #### Answer 1 - (a)
#
# ![IMG_0024.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (b) Find a cubic polynomial
#
# $f_{2}(x) = a_{2} + b_{2}x + c_{2}x^{2} + d_{2}x^{3}$
#
# such that $f(x) = f_{2}(x)$ for all $x > ξ$. Express $a_{2}, b_{2}, c_{2}, d_{2}$ in terms of $β_{0}, β_{1}, β_{2}, β_{3}, β_{4}$ We have now established that $f(x)$ is a piecewise polynomial.

# %% [markdown]
# #### Answer 1 - (b)
#
# ![IMG_0025.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (c) Show that $f_{1}(ξ) = f_{2}(ξ)$. That is, $f(x)$ is continuous at ξ.

# %% [markdown]
# #### Answer 1 -(c)
#
# ![IMG_0026.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (d) Show that $f_{1}^{'}(ξ) = f_{2}^{'}(ξ)$. That is, $f^{'}(x)$ is continuous at ξ.

# %% [markdown]
# #### Answer 1 - (d)
#
# ![IMG_0027.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (e) Show that $f_{1}^{''}(ξ) = f_{2}^{''}(ξ)$. That is, $f^{''}(x)$ is continuous at ξ.

# %% [markdown]
# #### Answer 1 - (e)
#
# ![IMG_0028.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question - 2 . Suppose that a curve $gˆ$ is computed to smoothly ft a set of n points using the following formula:
#
# $gˆ = arg min_{g}(∑_{i=1}^{n}(y_{i} - g(x_{i}))^{2} + λ ∫[g^{m}(x)]^{2}dx)$
#
# where $g^{m}$ represents the mth derivative of g (and $g^{0} = g$). Provide
# example sketches of $gˆ$ in each of the following scenarios.

# %% [markdown]
# #### (a) - (e)
#
# (a) λ = ∞, m = 0.
#
# (b) λ = ∞, m = 1.
#
# (c) λ = ∞, m = 2.
#
# (d) λ = ∞, m = 3.
#
# (e) λ = 0, m = 3.

# %% [markdown]
# #### Answer 2 - (a) -(e)
#
# ![IMG_0029.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question -3. Suppose we ft a curve with basis functions $b_1(X) = X, b_{2}(X) = (X − 1)^{2}I(X ≥ 1). (Note that I(X ≥ 1) equals 1 for X ≥ 1 and 0 otherwise.) We ft the linear regression model
#
# $Y = β_{0} + β_{1}b_{1}(X) + β_{2}b_{2}(X) + ϵ$
#
# and obtain coefficient estimates $βˆ0 = 1, βˆ1 = 1, βˆ2 = −2$. Sketch the
# estimated curve between $X = −2$ and $X = 2$. Note the intercepts,
# slopes, and other relevant information.

# %% [markdown]
# #### Answer 3
#
# ![IMG_0030.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question -4. Suppose we ft a curve with basis functions $b_1(X) = I(0 ≤ X ≤ 2) −(X −1)I(1 ≤ X ≤ 2), b_{2}(X) =(X −3)I(3 ≤ X ≤ 4) +I(4 < X ≤ 5). (Note that I(X ≥ 1) equals 1 for X ≥ 1 and 0 otherwise.) We ft the linear regression model
#
# $Y = β_{0} + β_{1}b_{1}(X) + β_{2}b_{2}(X) + ϵ$
#
# and obtain coefficient estimates $βˆ0 = 1, βˆ1 = 1, βˆ2 = 3$. Sketch the
# estimated curve between $X = −2$ and $X = 6$. Note the intercepts,
# slopes, and other relevant information.

# %% [markdown]
# #### Answers 4
#
# ![IMG_0031.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Question -5. (a) - (e) Consider two curves, $g_{1}ˆ and g_{2}$ˆ, defned by
#
# $g_{1}ˆ = arg min_{g}(∑_{i=1}^{n}(y_{i} - g(x_{i}))^{2} + λ ∫[g^{3}(x)]^{2}dx)$
#
# $g_{2}ˆ = arg min_{g}(∑_{i=1}^{n}(y_{i} - g(x_{i}))^{2} + λ ∫[g^{4}(x)]^{2}dx)$
#
# (a) As λ → ∞, will  $g_{1}ˆ or  g_{2}ˆ$ have the smaller training RSS?
#
# (b) As λ → ∞, will   $g_{1}ˆ or  g_{2}ˆ$ have the smaller test RSS?
#
# (c) For λ = 0, will  $g_{1}ˆ or  g_{2}ˆ$ have the smaller training and test RSS?

# %% [markdown]
# #### Answer 5 (a) - (e)
#
# ![IMG_0032.jpg](data:image/jpeg;base64,...)
